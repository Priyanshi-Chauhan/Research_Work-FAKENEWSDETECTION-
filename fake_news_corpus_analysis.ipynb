# %% [markdown]
# # SETUP AND IMPORT LIBRARIES for fake_news_sample(1)

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv("news_sample.csv")

# %% [markdown]
#  # Analysis

# %%
len(df)
# Out:
# 250

# %%
df.head()
# Out:
#    Unnamed: 0   id                domain        type  \
# 0           0  141               awm.com  unreliable
# 1           1  256     beforeitsnews.com        fake
# 2           2  700           cnnnext.com  unreliable
# 3           3  768               awm.com  unreliable
# 4           4  791  bipartisanreport.com   clickbait
#
#                                                  url  \
# 0  http://awm.com/church-congregation-brings-gift...
# 1  http://beforeitsnews.com/awakening-start-here/...
# 2  http://www.cnnnext.com/video/18526/never-hike-...
# 3  http://awm.com/elusive-alien-of-the-sea-caught...
# 4  http://bipartisanreport.com/2018/01/21/trumps-...
#
#                                              content  \
# 0  Sometimes the power of Christmas will make you...
# 1  AWAKENING OF 12 STRANDS of DNA – “Reconnecting...
# 2  Never Hike Alone: A Friday the 13th Fan Film U...
# 3  When a rare shark was caught, scientists were ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        250 non-null    int64
#  1   id                250 non-null    int64
#  2   domain            250 non-null    object
#  3   type              238 non-null    object
#  4   url               250 non-null    object
#  5   content           250 non-null    object
#  6   scraped_at        250 non-null    object
#  7   inserted_at       250 non-null    object
#  8   updated_at        250 non-null    object
#  9   title             250 non-null    object
#  10  authors           170 non-null    object
#  11  keywords          0 non-null      float64
#  12  meta_keywords     250 non-null    object
#  13  meta_description  54 non-null     object
#  14  tags              27 non-null     object
#  15  summary           0 non-null      float64
# ...

# %%
df.describe(include='all')
# Out:
#         Unnamed: 0            id             domain  type  \
# count   250.000000    250.000000                250   238
# unique         NaN           NaN                 29    10
# top            NaN           NaN  beforeitsnews.com  fake
# freq           NaN           NaN                155   155
# mean    124.500000  20241.560000                NaN   NaN
# std      72.312977  11515.412728                NaN   NaN
# min       0.000000    141.000000                NaN   NaN
# 25%      62.250000  11033.500000                NaN   NaN
# 50%     124.500000  21065.000000                NaN   NaN
# 75%     186.750000  29073.750000                NaN   NaN
# max     249.000000  39558.000000                NaN   NaN
#
#                                                       url  \
# count                                                 250
# unique                                                250
# top     http://canadafreepress.com/article/government-...
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'domain', 'type', 'url', 'content', 'scraped_at',
#        'inserted_at', 'updated_at', 'title', 'authors', 'keywords',
#        'meta_keywords', 'meta_description', 'tags', 'summary'],
#       dtype='object')

# %%
df.shape
# Out:
# (250, 16)

# %% [markdown]
# # checking for null values in the dataset

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum().plot(kind='bar',ylim=(0,len(df)),title='Nan values per column')

# %% [markdown]
# # Attribute analysis

# %%
df['type'].value_counts().plot(kind='bar', title='distribution of labels')

# %%
df=df.drop(columns=['meta_description', 'tags', 'summary','keywords','Unnamed: 0'])    # According to Nan values

# %% [markdown]
# ### Now dropping out irrelevant data like id, scraped_at,inserted_at,updated_at

# %%
df=df.drop(columns=["id","scraped_at","inserted_at","updated_at"])

# %%
df.shape
# Out:
# (250, 7)

# %%
df
# Out:
#                    domain        type  \
# 0                 awm.com  unreliable
# 1       beforeitsnews.com        fake
# 2             cnnnext.com  unreliable
# 3                 awm.com  unreliable
# 4    bipartisanreport.com   clickbait
# ..                    ...         ...
# 245     beforeitsnews.com        fake
# 246     beforeitsnews.com        fake
# 247       www.newsmax.com         NaN
# 248       www.newsmax.com         NaN
# 249       www.newsmax.com         NaN
#
#                                                    url  \
# 0    http://awm.com/church-congregation-brings-gift...
# 1    http://beforeitsnews.com/awakening-start-here/...
# 2    http://www.cnnnext.com/video/18526/never-hike-...
# 3    http://awm.com/elusive-alien-of-the-sea-caught...
# 4    http://bipartisanreport.com/2018/01/21/trumps-...
# ..                                                 ...
# 245  http://beforeitsnews.com/economy/2017/12/priso...
# ...

# %%
from sklearn.feature_selection import chi2

# %%
from sklearn.feature_selection import SelectKBest

# %%
Y=df.iloc[:,2]

# %%
Y.head(n=10)
# Out:
# 0    unreliable
# 1          fake
# 2    unreliable
# 3    unreliable
# 4     clickbait
# 5    unreliable
# 6    conspiracy
# 7          fake
# 8          fake
# 9    conspiracy
# Name: type, dtype: object

# %%
df.columns
# Out:
# Index(['id', 'domain', 'type', 'url', 'content', 'scraped_at', 'inserted_at',
#        'updated_at', 'title', 'authors', 'meta_keywords'],
#       dtype='object')

# %%
X=pd.DataFrame(df,columns=['id', 'domain', 'url', 'content', 'scraped_at', 'inserted_at',
       'updated_at', 'title', 'authors', 'meta_keywords'])

# %%
X
# Out:
#         id                domain  \
# 0      141               awm.com
# 1      256     beforeitsnews.com
# 2      700           cnnnext.com
# 3      768               awm.com
# 4      791  bipartisanreport.com
# ..     ...                   ...
# 245  39259     beforeitsnews.com
# 246  39468     beforeitsnews.com
# 247  39477       www.newsmax.com
# 248  39550       www.newsmax.com
# 249  39558       www.newsmax.com
#
#                                                    url  \
# 0    http://awm.com/church-congregation-brings-gift...
# 1    http://beforeitsnews.com/awakening-start-here/...
# 2    http://www.cnnnext.com/video/18526/never-hike-...
# 3    http://awm.com/elusive-alien-of-the-sea-caught...
# 4    http://bipartisanreport.com/2018/01/21/trumps-...
# ..                                                 ...
# 245  http://beforeitsnews.com/economy/2017/12/priso...
# 246  http://beforeitsnews.com/diy/2017/11/4-useful-...
# 247  https://www.newsmax.com/politics/michael-hayde...
# ...

# %%
best_feature=SelectKBest(score_func=chi2,k=6)

# %%
fit=best_feature.fit(X,Y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-f3add50ef209> in <module>
# ----> 1 fit=best_feature.fit(X,Y)
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py in fit(self, X, y)
#     343         """
#     344         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc'],
# --> 345                                    multi_output=True)
#     346
#     347         if not callable(self.score_func):
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
# ...
